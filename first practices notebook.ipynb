# %%
a=10
print(a)
# Out:
# 10

# %%
s=20
print(s)
# Out:
# 20

# %%
import pandas as pd
ab= pd.read_csv("https://raw.githubusercontent.com/9971anand/practicsfile/main/Employees.csv")
ab
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents'

# %%
s=10
print(s)
# Out:
# 10

# %%
s="ANAND KUMAR"
print(s)
# Out:
# ANAND KUMAR

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Downloads\Employees.csv")
df
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...

# %%
df
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...

# %%
import pandas as pd
sr=pd.read_csv("https://raw.githubusercontent.com/9971anand/practicsfile/main/Employees.csv")
sr
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...

# %%
sr
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...
